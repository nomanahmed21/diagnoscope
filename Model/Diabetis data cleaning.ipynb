# %%
import pandas as pd

# %%
df = pd.read_excel("diabetes_1000.xlsx")

# %%
df.head()
# Out:
#    Age  Gender Polyuria Polydipsia Sudden weight loss Weakness Polyphagia  \
# 0   35  Female      Yes         No                 No       No        Yes
# 1   52  Female      Yes        Yes                Yes       No        Yes
# 2   52  Female      Yes        Yes                Yes       No        Yes
# 3   41    Male      Yes        Yes                Yes      Yes        Yes
# 4   53    Male       No         No                 No       No        Yes
#
#   Genital thrush Visual blurring Itching Irritability Delayed healing  \
# 0            Yes              No      No           No              No
# 1             No              No      No           No              No
# 2             No             Yes     Yes           No              No
# 3             No              No      No           No             Yes
# 4             No              No      No           No              No
#
#   Partial paresis Muscle stiffness Alopecia Obesity     Class
# 0             Yes               No       No      No  Positive
# 1             Yes              Yes      Yes      No  Positive
# 2              No              Yes      Yes     Yes  Positive
# 3             Yes              Yes       No     Yes  Positive
# 4              No               No       No      No  Negative

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 10000 non-null  int64
#  1   Gender              10000 non-null  object
#  2   Polyuria            10000 non-null  object
#  3   Polydipsia          10000 non-null  object
#  4   Sudden weight loss  10000 non-null  object
#  5   Weakness            10000 non-null  object
#  6   Polyphagia          10000 non-null  object
#  7   Genital thrush      10000 non-null  object
#  8   Visual blurring     10000 non-null  object
#  9   Itching             10000 non-null  object
#  10  Irritability        10000 non-null  object
#  11  Delayed healing     10000 non-null  object
#  12  Partial paresis     10000 non-null  object
#  13  Muscle stiffness    10000 non-null  object
#  14  Alopecia            10000 non-null  object
#  15  Obesity             10000 non-null  object
#  16  Class               10000 non-null  object
# dtypes: int64(1), object(16)
# memory usage: 1.3+ MB

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, LabelEncoder, OneHotEncoder

# %%
age_col = ['Age']
gender_col =['Gender']
labels = df["Class"]
df.drop(columns=["Age","Gender", "Class" ], inplace = True)

# %%
symptoms_col = df

# %%
symptoms_col
# Out:
#      Polyuria Polydipsia Sudden weight loss Weakness Polyphagia  \
# 0         Yes         No                 No       No        Yes
# 1         Yes        Yes                Yes       No        Yes
# 2         Yes        Yes                Yes       No        Yes
# 3         Yes        Yes                Yes      Yes        Yes
# 4          No         No                 No       No        Yes
# ...       ...        ...                ...      ...        ...
# 9995      Yes         No                Yes      Yes        Yes
# 9996      Yes        Yes                 No      Yes        Yes
# 9997      Yes        Yes                Yes      Yes        Yes
# 9998       No         No                 No       No        Yes
# 9999      Yes        Yes                Yes      Yes        Yes
#
#      Genital thrush Visual blurring Itching Irritability Delayed healing  \
# 0               Yes              No      No           No              No
# 1                No              No      No           No              No
# 2                No             Yes     Yes           No              No
# 3                No              No      No           No             Yes
# 4                No              No      No           No              No
# ...             ...             ...     ...          ...             ...
# 9995             No             Yes     Yes           No              No
# 9996            Yes             Yes      No           No             Yes
# 9997            Yes             Yes     Yes          Yes             Yes
# 9998             No              No     Yes           No              No
# 9999            Yes             Yes     Yes          Yes              No
#
#      Partial paresis Muscle stiffness Alopecia Obesity
# 0                Yes               No       No      No
# 1                Yes              Yes      Yes      No
# 2                 No              Yes      Yes     Yes
# 3                Yes              Yes       No     Yes
# 4                 No               No       No      No
# ...              ...              ...      ...     ...
# 9995              No               No       No      No
# 9996             Yes               No       No      No
# 9997             Yes              Yes       No      No
# 9998              No               No       No      No
# 9999             Yes              Yes       No      No
#
# [10000 rows x 14 columns]

# %%
def build_pipeline(age_col,symptoms_col, gender_col):
    age_pipeline = Pipeline([
    ("scale",StandardScaler())
    ])

    symptoms_pipeline = Pipeline([
        ("encoder", OrdinalEncoder())
    ])
    gender_encoder = Pipeline([
        ("enoder", OneHotEncoder())
    ])
    
    full_pipeline = ColumnTransformer([
        ("age", age_pipeline, age_col),
        ("symptoms", symptoms_pipeline, symptoms_col),
        ("gender", gender_encoder, gender_col)
    ]) 
    return full_pipeline

# %%
label_pipeline = Pipeline([
    ("encoder", LabelEncoder())
])

# %%
from sklearn.model_selection import train_test_split

# %%
df2 = pd.read_excel("diabetes_1000.xlsx")

# %%
pipeline = build_pipeline(age_col,symptoms_col, gender_col)

# %%
pipeline
# Out:
# ColumnTransformer(transformers=[('age',
#                                  Pipeline(steps=[('scale', StandardScaler())]),
#                                  0       35
# 1       52
# 2       52
# 3       41
# 4       53
#         ..
# 9995    39
# 9996    57
# 9997    58
# 9998    33
# 9999    50
# Name: Age, Length: 10000, dtype: int64),
#                                 ('symptoms',
#                                  Pipeline(steps=[('encoder',
#                                                   OrdinalEncoder())]),
#                                       Polyuria Polydipsia Sudden weight loss Weakness Polyphagia  \
# 0         Yes         No                 No       No        Yes
# 1         Yes        Yes                Yes       No        Yes
# 2         Yes        Yes                Yes       No        Yes
# 3         Yes        Yes                Yes      Yes        Yes
# 4          No         No                 No       No        Yes
# ....
#      Partial paresis Muscle stiffness Alopecia Obesity
# 0                Yes               No       No      No
# 1                Yes              Yes      Yes      No
# 2                 No              Yes      Yes     Yes
# 3                Yes              Yes       No     Yes
# 4                 No               No       No      No
# ...              ...              ...      ...     ...
# 9995              No               No       No      No
# 9996             Yes               No       No      No
# 9997             Yes              Yes       No      No
# 9998              No               No       No      No
# 9999             Yes              Yes       No      No
#
# [10000 rows x 14 columns]),
#                                 ('gender',
#                                  Pipeline(steps=[('enoder', OneHotEncoder())]),
#                                  0       Female
# 1       Female
# 2       Female
# 3         Male
# 4         Male
#          ...
# 9995    Female
# 9996    Female
# 9997    Female
# 9998      Male
# 9999    Female
# Name: Gender, Length: 10000, dtype: object)])

# %%
# df2 = df2.drop("Class", axis= 1)
x= pipeline.fit_transform(df2)
df2
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:312, in _get_column_indices_for_bool_or_int(key, n_columns)
#     311 try:
# --> 312     idx = _safe_indexing(np.arange(n_columns), key)
#     313 except IndexError as e:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:267, in _safe_indexing(X, indices, axis)
#     266 elif hasattr(X, "shape"):
# --> 267     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     268 else:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:33, in _array_indexing(array, key, key_dtype, axis)
#      32     key = list(key)
# ---> 33 return array[key, ...] if axis == 0 else array[:, key]
#
# IndexError: index 35 is out of bounds for axis 0 with size 16
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 # df2 = df2.drop("Class", axis= 1)
# ----> 2 x= pipeline.fit_transform(df2)
#       3 df2
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py:313, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     311 @wraps(f)
#     312 def wrapped(self, X, *args, **kwargs):
# --> 313     data_to_wrap = f(self, X, *args, **kwargs)
#     314     if isinstance(data_to_wrap, tuple):
#     315         # only wrap the first output for cross decomposition
#     316         return_tuple = (
#     317             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     318             *data_to_wrap[1:],
#     319         )
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:968, in ColumnTransformer.fit_transform(self, X, y, **params)
#     965 self._validate_transformers()
#     966 n_samples = _num_samples(X)
# --> 968 self._validate_column_callables(X)
#     969 self._validate_remainder(X)
#     971 if _routing_enabled():
#
# File ~\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py:536, in ColumnTransformer._validate_column_callables(self, X)
#     534         columns = columns(X)
#     535     all_columns.append(columns)
# --> 536     transformer_to_input_indices[name] = _get_column_indices(X, columns)
#     538 self._columns = all_columns
#     539 self._transformer_to_input_indices = transformer_to_input_indices
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:335, in _get_column_indices(X, key)
#     333     return []
#     334 elif key_dtype in ("bool", "int"):
# --> 335     return _get_column_indices_for_bool_or_int(key, n_columns)
#     336 else:
#     337     try:
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\_indexing.py:314, in _get_column_indices_for_bool_or_int(key, n_columns)
#     312     idx = _safe_indexing(np.arange(n_columns), key)
#     313 except IndexError as e:
# --> 314     raise ValueError(
#     315         f"all features must be in [0, {n_columns - 1}] or [-{n_columns}, 0]"
#     316     ) from e
#     317 return np.atleast_1d(idx).tolist()
#
# ValueError: all features must be in [0, 15] or [-16, 0]

# %%
# Out:
#      Polyuria Polydipsia Sudden weight loss Weakness Polyphagia  \
# 0         Yes         No                 No       No        Yes
# 1         Yes        Yes                Yes       No        Yes
# 2         Yes        Yes                Yes       No        Yes
# 3         Yes        Yes                Yes      Yes        Yes
# 4          No         No                 No       No        Yes
# ...       ...        ...                ...      ...        ...
# 9995      Yes         No                Yes      Yes        Yes
# 9996      Yes        Yes                 No      Yes        Yes
# 9997      Yes        Yes                Yes      Yes        Yes
# 9998       No         No                 No       No        Yes
# 9999      Yes        Yes                Yes      Yes        Yes
#
#      Genital thrush Visual blurring Itching Irritability Delayed healing  \
# 0               Yes              No      No           No              No
# 1                No              No      No           No              No
# 2                No             Yes     Yes           No              No
# 3                No              No      No           No             Yes
# 4                No              No      No           No              No
# ...             ...             ...     ...          ...             ...
# 9995             No             Yes     Yes           No              No
# 9996            Yes             Yes      No           No             Yes
# 9997            Yes             Yes     Yes          Yes             Yes
# 9998             No              No     Yes           No              No
# 9999            Yes             Yes     Yes          Yes              No
#
#      Partial paresis Muscle stiffness Alopecia Obesity
# 0                Yes               No       No      No
# 1                Yes              Yes      Yes      No
# 2                 No              Yes      Yes     Yes
# 3                Yes              Yes       No     Yes
# 4                 No               No       No      No
# ...              ...              ...      ...     ...
# 9995              No               No       No      No
# 9996             Yes               No       No      No
# 9997             Yes              Yes       No      No
# 9998              No               No       No      No
# 9999             Yes              Yes       No      No
#
# [10000 rows x 14 columns]

# %%
df2
# Out:
#       Age  Gender Polyuria Polydipsia Sudden weight loss Weakness Polyphagia  \
# 0      35  Female      Yes         No                 No       No        Yes
# 1      52  Female      Yes        Yes                Yes       No        Yes
# 2      52  Female      Yes        Yes                Yes       No        Yes
# 3      41    Male      Yes        Yes                Yes      Yes        Yes
# 4      53    Male       No         No                 No       No        Yes
# ...   ...     ...      ...        ...                ...      ...        ...
# 9995   39  Female      Yes         No                Yes      Yes        Yes
# 9996   57  Female      Yes        Yes                 No      Yes        Yes
# 9997   58  Female      Yes        Yes                Yes      Yes        Yes
# 9998   33    Male       No         No                 No       No        Yes
# 9999   50  Female      Yes        Yes                Yes      Yes        Yes
#
#      Genital thrush Visual blurring Itching Irritability Delayed healing  \
# 0               Yes              No      No           No              No
# 1                No              No      No           No              No
# 2                No             Yes     Yes           No              No
# 3                No              No      No           No             Yes
# 4                No              No      No           No              No
# ...             ...             ...     ...          ...             ...
# 9995             No             Yes     Yes           No              No
# 9996            Yes             Yes      No           No             Yes
# 9997            Yes             Yes     Yes          Yes             Yes
# 9998             No              No     Yes           No              No
# 9999            Yes             Yes     Yes          Yes              No
#
#      Partial paresis Muscle stiffness Alopecia Obesity     Class
# 0                Yes               No       No      No  Positive
# 1                Yes              Yes      Yes      No  Positive
# 2                 No              Yes      Yes     Yes  Positive
# 3                Yes              Yes       No     Yes  Positive
# 4                 No               No       No      No  Negative
# ...              ...              ...      ...     ...       ...
# 9995              No               No       No      No  Positive
# 9996             Yes               No       No      No  Positive
# 9997             Yes              Yes       No      No  Positive
# 9998              No               No       No      No  Negative
# 9999             Yes              Yes       No      No  Positive
#
# [10000 rows x 17 columns]
